# %%
import numpy as np
import matplotlib.pyplot as plt

from nonparam import KernalSmooth

# %%
### 生成数据：U, y
n = 3000
U = np.random.uniform(0, 2*np.pi, n)
error = np.random.randn(n)
y =  3*np.sin(U) + error

# %%
#############################
####  核光滑
#############################
estimator = KernalSmooth()
y_hat = estimator.fitpredict(U,y,U,0.3,"gaussian")

plt.scatter(U,y)
plt.scatter(U,y_hat)
plt.show()
